# %% [markdown]
# <a href="https://colab.research.google.com/github/zohoor7/DIPLOMA_PART1/blob/main/Lesson_01_pythone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **this is Lab 1**

# %% [markdown]
# **البايثون**: هي لغة برمجة سهلة تُستخدم للتواصل مع الكمبيوتر.ليحوّل الكود البشري إلى لغة يفهمها الكمبيوتر الكمبيوتر يفهم فقط 0,1 لذلك نحتاج
#
# **Interpreter** (مفسر او مترجم)

# %% [markdown]
# **Python Basics - ساسيات Python**

# %% [markdown]
# #**Data Types -  (أنواع البيانات)**
#
# **int → integers (مثال: 10)**
#
# **float → decimal numbers (مثال: 3.14)**
#
# **str → text/string (مثال: "Hello")**
#
# **bool → True or False**

# %%
x = 3 #Assinging
print(x)

# %% [markdown]
# Print Function (طباعة)
#
# Display output in console

# %%
print(type(x))

# %% [markdown]
#  Operators (العمليات الحسابية)
#
# Addition: +
#
# Subtraction: -
#
# Multiplication: *
#
# Division: /

# %%
print(x+1)

# %%
print(x-1)

# %%
print(x*2)

# %%
print(x/3)

# %%
y= x*2
print(y)

# %%
z=3.5
print(type(z))

# %%
A=12
B=3.4
C=A+B
D=A*B
print(C)
print(D)

# %% [markdown]
# #Boolean

# %%
tr = True
fa = False
print(type(tr))

# %%
print(tr and fa)   # Logical AND, t * f = 0 , t = 1 , f = 0
print(tr or fa)    # Logical OR,  t + f
print(not tr)     # Logical NOT, reverse
print(tr != fa)    # Logical XOR, 1 notequal 0 = true

# %%
print((tr != fa) and (tr))

# %% [markdown]
# #string

# %%
h="hello"
w = "word"
print(w)

# %%
hw=h+" "+w
print(hw)
